# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A062/Nlp-lab/blob/main/Deduction_Ex_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rules = {
    "human": "wet"
}

entity = "Socrates"
category = "human"

if category in rules:
    conclusion = f"{entity} is {rules[category]}."
else:
    conclusion = f"No rule for {category}."

print(conclusion)
# Out:
# Socrates is wet.
