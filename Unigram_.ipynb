# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A062/Nlp-lab/blob/main/Unigram_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

text = input("Enter text: ").lower().split()
counts = Counter(text)
total = sum(counts.values())

print("\nUnigram probabilities:")
for w, c in counts.items():
    print(f"{w}: {c/total:.4f}")
# Out:
# Enter text: I love natural language processing with python
#
# Unigram probabilities:
# i: 0.1429
# love: 0.1429
# natural: 0.1429
# language: 0.1429
# processing: 0.1429
# with: 0.1429
# python: 0.1429
