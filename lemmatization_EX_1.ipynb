# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A062/Nlp-lab/blob/main/lemmatization_EX_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

words = ['cats', 'running','better', 'wolves']
lemmas = [lemmatizer.lemmatize(word, pos='v') for word in words]

print(lemmas)
# Out:
# ['cat', 'run', 'better', 'wolves']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
